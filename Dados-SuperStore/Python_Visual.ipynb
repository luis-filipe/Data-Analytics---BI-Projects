# %% [markdown]
# # Importação de Bibliotecas

# %%
# Manipulação de dados
import pandas as pd
import numpy as np

# Visualização
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Carregamento e Vizualização de Dados

# %% [markdown]
# ## Leitura

# %%
df = pd.read_excel("/content/Superstore.xlsx", dtype=str, keep_default_na=False, na_values=["", "NA", "N/A", "null"])

# %% [markdown]
# ## Vizualizar primeiras linhas

# %%
df.head(10)
# Out:
#   Linha ID       ID Pedido       Data do Pedido        Data do Envio  \
# 0        1  CA-2013-152156  2013-11-09 00:00:00  2013-11-12 00:00:00
# 1        2  CA-2013-152156  2013-11-09 00:00:00  2013-11-12 00:00:00
# 2        3  CA-2013-138688  2013-06-13 00:00:00  2013-06-17 00:00:00
# 3        4  US-2012-108966  2012-10-11 00:00:00  2012-10-18 00:00:00
# 4        5  US-2012-108966  2012-10-11 00:00:00  2012-10-18 00:00:00
# 5        6  CA-2011-115812  2011-06-09 00:00:00  2011-06-14 00:00:00
# 6        7  CA-2011-115812  2011-06-09 00:00:00  2011-06-14 00:00:00
# 7        8  CA-2011-115812  2011-06-09 00:00:00  2011-06-14 00:00:00
# 8        9  CA-2011-115812  2011-06-09 00:00:00  2011-06-14 00:00:00
# 9       10  CA-2011-115812  2011-06-09 00:00:00  2011-06-14 00:00:00
#
#     Mode de Envio ID Vendedor Nome do Vendedor   Segmento           Pais  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States
# 5  Standard Class    BH-11710  Brosina Hoffman   Consumer  United States
# 6  Standard Class    BH-11710  Brosina Hoffman   Consumer  United States
# 7  Standard Class    BH-11710  Brosina Hoffman   Consumer  United States
# 8  Standard Class    BH-11710  Brosina Hoffman   Consumer  United States
# 9  Standard Class    BH-11710  Brosina Hoffman   Consumer  United States
#
#             Cidade  ... Codigo Postal Região       Produto ID  \
# 0        Henderson  ...         42420  South  FUR-BO-10001798
# 1        Henderson  ...         42420  South  FUR-CH-10000454
# 2      Los Angeles  ...         90036   West  OFF-LA-10000240
# 3  Fort Lauderdale  ...         33311  South  FUR-TA-10000577
# 4  Fort Lauderdale  ...         33311  South  OFF-ST-10000760
# 5      Los Angeles  ...         90032   West  FUR-FU-10001487
# 6      Los Angeles  ...         90032   West  OFF-AR-10002833
# 7      Los Angeles  ...         90032   West  TEC-PH-10002275
# 8      Los Angeles  ...         90032   West  OFF-BI-10003910
# 9      Los Angeles  ...         90032   West  OFF-AP-10002892
#
#          Categoria Sub-Categoria  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# 2  Office Supplies        Labels
# 3        Furniture        Tables
# 4  Office Supplies       Storage
# 5        Furniture   Furnishings
# 6  Office Supplies           Art
# 7       Technology        Phones
# 8  Office Supplies       Binders
# 9  Office Supplies    Appliances
#
#                                      Nome do Produto         Valor venda  \
# 0                  Bush Somerset Collection Bookcase              261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9399999999999
# 2  Self-Adhesive Address Labels for Typewriters b...               14.62
# 3      Bretford CR4500 Series Slim Rectangular Table            957.5775
# 4                     Eldon Fold 'N Roll Cart System  22.368000000000002
# 5  Eldon Expressions Wood and Plastic Desk Access...               48.86
# 6                                         Newell 322                7.28
# 7                     Mitel 5320 IP Phone VoIP phone             907.152
# 8  DXL Angle-View Binders with Locking Rings by S...              18.504
# 9                   Belkin F5C206VTEL 6 Outlet Surge               114.9
#
#   Quantidade Desconto                Lucro
# 0          2        0              41.9136
# 1          3        0   219.58199999999997
# 2          2        0   6.8713999999999995
# 3          5     0.45  -383.03100000000006
# 4          2      0.2    2.516399999999999
# 5          7        0   14.169399999999996
# 6          4        0   1.9656000000000002
# 7          6      0.2    90.71520000000004
# 8          3      0.2               5.7825
# 9          5        0    34.46999999999999
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Informarções gerais da tabela

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Linha ID          9994 non-null   object
#  1   ID Pedido         9994 non-null   object
#  2   Data do Pedido    9994 non-null   object
#  3   Data do Envio     9994 non-null   object
#  4   Mode de Envio     9994 non-null   object
#  5   ID Vendedor       9994 non-null   object
#  6   Nome do Vendedor  9994 non-null   object
#  7   Segmento          9994 non-null   object
#  8   Pais              9994 non-null   object
#  9   Cidade            9994 non-null   object
#  10  Estado            9994 non-null   object
#  11  Codigo Postal     9994 non-null   object
#  12  Região            9994 non-null   object
#  13  Produto ID        9994 non-null   object
#  14  Categoria         9994 non-null   object
#  15  Sub-Categoria     9994 non-null   object
#  16  Nome do Produto   9994 non-null   object
#  17  Valor venda       9994 non-null   object
#  18  Quantidade        9994 non-null   object
#  19  Desconto          9994 non-null   object
#  20  Lucro             9994 non-null   object
# dtypes: object(21)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Contagem de valores nulos

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Linha ID            0
# ID Pedido           0
# Data do Pedido      0
# Data do Envio       0
# Mode de Envio       0
# ID Vendedor         0
# Nome do Vendedor    0
# Segmento            0
# Pais                0
# Cidade              0
# Estado              0
# Codigo Postal       0
# Região              0
# Produto ID          0
# Categoria           0
# Sub-Categoria       0
# Nome do Produto     0
# Valor venda         0
# Quantidade          0
# Desconto            0
# Lucro               0
# dtype: int64

# %% [markdown]
# ## Contagem valores unicos por coluna

# %%
df.nunique().sort_values(ascending=False)
# Out:
# Linha ID            9994
# Lucro               7545
# Valor venda         6144
# ID Pedido           5009
# Produto ID          1862
# Nome do Produto     1841
# Data do Envio       1334
# Data do Pedido      1238
# ID Vendedor          793
# Nome do Vendedor     793
# Codigo Postal        631
# Cidade               531
# Estado                49
# Sub-Categoria         17
# Quantidade            14
# Desconto              12
# Mode de Envio          4
# Região                 4
# Segmento               3
# Categoria              3
# Pais                   1
# dtype: int64

# %% [markdown]
# # Limpeza dos Dados (Data Cleaning)

# %% [markdown]
# ## Convertendo Para Datas

# %%
df["Data do Pedido"] = pd.to_datetime(df["Data do Pedido"])
df["Data do Envio"] = pd.to_datetime(df["Data do Envio"])

# %% [markdown]
# ## Convertendo Para Numericos

# %%
numericos = ["Valor venda", "Quantidade", "Desconto", "Lucro"]

for col in cols_numericas:
    df[col] = df[col].astype(float)

# %% [markdown]
# ## Verificação valores faltantes

# %%
df.replace(["", " ", "NA", "N/A", "null", "-"], np.nan, inplace=True)
df.isna().sum()
# Out:
# Linha ID            0
# ID Pedido           0
# Data do Pedido      0
# Data do Envio       0
# Mode de Envio       0
# ID Vendedor         0
# Nome do Vendedor    0
# Segmento            0
# Pais                0
# Cidade              0
# Estado              0
# Codigo Postal       0
# Região              0
# Produto ID          0
# Categoria           0
# Sub-Categoria       0
# Nome do Produto     0
# Valor venda         0
# Quantidade          0
# Desconto            0
# Lucro               0
# dtype: int64

# %% [markdown]
# ## Criando Coluna Ano, Mes e Dia

# %%
df["Ano"] = df["Data do Pedido"].dt.year
df["Mes"] = df["Data do Pedido"].dt.month
df["Dia"] = df["Data do Pedido"].dt.day
df["Envio Dias"] = (df["Data do Envio"] - df["Data do Pedido"]).dt.days

# %% [markdown]
# ## Criando a coluna "Valor Unitário"

# %%
df['Valor Unitario'] = df['Valor venda'] / df['Quantidade']

# %%
# Conferindo as primeiras linhas
df[['Valor venda', 'Quantidade', 'Valor Unitario']].head()
# Out:
#    Valor venda  Quantidade  Valor Unitario
# 0     261.9600         2.0        130.9800
# 1     731.9400         3.0        243.9800
# 2      14.6200         2.0          7.3100
# 3     957.5775         5.0        191.5155
# 4      22.3680         2.0         11.1840

# %% [markdown]
# ## Criando Margem %

# %%
df['Margem'] = df['Lucro'] / df['Valor venda']

# %% [markdown]
# ## Lista de colunas para manter apenas 2 casas decimais

# %%
colunas_duas_casas = ['Valor venda', 'Lucro', 'Valor Unitario', 'Margem']

# Arredondar para 2 casas decimais
df[colunas_duas_casas] = df[colunas_duas_casas].round(2)

# Converter desconto para porcentagem (ex: 0.45 → 45.00)
df['Desconto'] = (df['Desconto'] * 100).round(2)

# %% [markdown]
# ## Remoção duplicada

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Detectar ouliers

# %%
df[["Valor venda", "Lucro"]].describe()
# Out:
#         Valor venda        Lucro
# count   9994.000000  9994.000000
# mean     229.857989    28.656783
# std      623.245113   234.260148
# min        0.440000 -6599.980000
# 25%       17.280000     1.730000
# 50%       54.490000     8.665000
# 75%      209.940000    29.360000
# max    22638.480000  8399.980000

# %% [markdown]
# ## Vizualização

# %%
df.head(10)
# Out:
#   Linha ID       ID Pedido Data do Pedido Data do Envio   Mode de Envio  \
# 0        1  CA-2013-152156     2013-11-09    2013-11-12    Second Class
# 1        2  CA-2013-152156     2013-11-09    2013-11-12    Second Class
# 2        3  CA-2013-138688     2013-06-13    2013-06-17    Second Class
# 3        4  US-2012-108966     2012-10-11    2012-10-18  Standard Class
# 4        5  US-2012-108966     2012-10-11    2012-10-18  Standard Class
# 5        6  CA-2011-115812     2011-06-09    2011-06-14  Standard Class
# 6        7  CA-2011-115812     2011-06-09    2011-06-14  Standard Class
# 7        8  CA-2011-115812     2011-06-09    2011-06-14  Standard Class
# 8        9  CA-2011-115812     2011-06-09    2011-06-14  Standard Class
# 9       10  CA-2011-115812     2011-06-09    2011-06-14  Standard Class
#
#   ID Vendedor Nome do Vendedor   Segmento           Pais           Cidade  \
# 0    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1    CG-12520      Claire Gute   Consumer  United States        Henderson
# 2    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5    BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 6    BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 7    BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 8    BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 9    BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
#
#    ... Valor venda Quantidade Desconto   Lucro   Ano Mes Dia  Envio Dias  \
# 0  ...      261.96        2.0      0.0   41.91  2013  11   9           3
# 1  ...      731.94        3.0      0.0  219.58  2013  11   9           3
# 2  ...       14.62        2.0      0.0    6.87  2013   6  13           4
# 3  ...      957.58        5.0     45.0 -383.03  2012  10  11           7
# 4  ...       22.37        2.0     20.0    2.52  2012  10  11           7
# 5  ...       48.86        7.0      0.0   14.17  2011   6   9           5
# 6  ...        7.28        4.0      0.0    1.97  2011   6   9           5
# 7  ...      907.15        6.0     20.0   90.72  2011   6   9           5
# 8  ...       18.50        3.0     20.0    5.78  2011   6   9           5
# 9  ...      114.90        5.0      0.0   34.47  2011   6   9           5
#
#    Valor Unitario  Margem
# 0          130.98    0.16
# 1          243.98    0.30
# 2            7.31    0.47
# 3          191.52   -0.40
# 4           11.18    0.11
# 5            6.98    0.29
# 6            1.82    0.27
# 7          151.19    0.10
# 8            6.17    0.31
# 9           22.98    0.30
#
# [10 rows x 27 columns]

# %% [markdown]
# # Análise Exploratória dos Dados (EDA)

# %% [markdown]
# ## Histogramas

# %%
for col in numericos:
    plt.figure(figsize=(8,4))
    plt.hist(df[col], bins=30)
    plt.title(f"Distribuição de {col}")
    plt.xlabel(col)
    plt.ylabel("Frequência")
    plt.show()

# %% [markdown]
# ## Boxplot

# %%
for col in numericos:
    plt.figure(figsize=(8,3))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot de {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# ## Matriz de Correlação

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[numericos].corr(), annot=True, cmap="Blues")
plt.title("Correlação entre variáveis numéricas")
plt.show()

# %% [markdown]
# ## Y em Função de X

# %%
pairs = [
    ("Valor venda", "Lucro"),
    ("Quantidade", "Valor venda"),
    ("Desconto", "Lucro")
]

for x, y in pairs:
    plt.figure(figsize=(7,5))
    sns.scatterplot(data=df, x=x, y=y)
    plt.title(f"{y} em função de {x}")
    plt.show()

# %% [markdown]
# ## Media valores por categoria

# %%
agrupamentos = [
    "Categoria",
    "Sub-Categoria",
    "Segmento",
    "Estado",
    "Cidade",
    "Região",
    "Nome do Vendedor"
]

for col in agrupamentos:
    print(f"\n#### {col.upper()} ####")
    display(df.groupby(col)[["Valor venda", "Lucro", "Quantidade"]].mean().sort_values("Valor venda", ascending=False))
# Out:
# #### CATEGORIA ####
#                  Valor venda      Lucro  Quantidade
# Categoria
# Technology        452.709296  78.752220    3.756903
# Furniture         349.834842   8.699250    3.785007
# Office Supplies   119.324091  20.326822    3.801195
# #### SUB-CATEGORIA ####
#                Valor venda       Lucro  Quantidade
# Sub-Categoria
# Copiers        2198.941324  817.909853    3.441176
# Machines       1645.553478   29.432348    3.826087
# Tables          648.794734  -55.566144    3.890282
# Chairs          532.332399   43.095786    3.818476
# Bookcases       503.859518  -15.230614    3.807018
# Phones          371.211586   50.074274    3.699663
# Storage         264.590532   25.152281    3.732861
# Supplies        245.650105   -6.258526    3.405263
# Appliances      230.755665   38.922682    3.710300
# Accessories     215.974594   54.111910    3.840000
# Binders         133.560571   19.843309    3.922521
# Furnishings      95.825622   13.645967    3.723093
# Envelopes        64.867638   27.417323    3.566929
# Paper            57.284117   24.856146    3.779562
# Labels           34.303022   15.236758    3.846154
# Art              34.068844    8.200716    3.768844
# Fasteners        13.936636    4.375668    4.211982
# #### SEGMENTO ####
#              Valor venda      Lucro  Quantidade
# Segmento
# Home Office   240.972075  33.818682    3.782389
# Corporate     233.823291  30.456586    3.843709
# Consumer      223.733614  25.836696    3.760547
# #### ESTADO ####
#                       Valor venda       Lucro  Quantidade
# Estado
# Wyoming               1603.140000  100.200000    4.000000
# Vermont                811.760909  204.089091    4.545455
# Nevada                 428.951282   85.045128    4.307692
# Rhode Island           404.070714  130.100536    3.553571
# Montana                372.623333  122.220000    3.733333
# Indiana                359.431946  123.375436    3.879195
# Missouri               336.441667   97.518030    3.818182
# Minnesota              335.541011  121.609101    3.719101
# Alabama                319.846557   94.866230    4.196721
# Virginia               315.342500   83.026473    3.986607
# West Virginia          302.455000   46.482500    4.500000
# Michigan               299.096510   95.933765    3.709804
# Oklahoma               298.233182   73.545000    3.742424
# Wisconsin              291.951000   76.379818    4.209091
# District of Columbia   286.502000  105.959000    4.000000
# Delaware               285.948646  103.930729    3.822917
# New York               275.599468   65.636871    3.744681
# New Jersey             275.110154   75.176077    3.492308
# Washington             273.994644   66.013103    3.721344
# New Hampshire          270.093333   63.203333    4.703704
# Georgia                266.825217   88.315272    3.831522
# Kentucky               263.250000   80.573094    3.762590
# Florida                233.612820   -8.875457    3.600522
# California             228.729445   38.171439    3.831584
# Maryland               225.766857   66.963429    4.000000
# North Carolina         223.305542  -30.083896    3.947791
# Louisiana              219.453095   52.287619    3.714286
# Massachusetts          212.106889   50.263111    3.637037
# Utah                   211.699245   48.047925    4.132075
# Idaho                  208.690000   39.368095    3.047619
# Mississippi            203.232830   59.867547    4.169811
# South Carolina         201.945476   42.120714    4.095238
# Pennsylvania           198.487206  -26.507785    3.667802
# Nebraska               196.445526   53.607632    3.578947
# Arkansas               194.635500   66.810833    4.000000
# Colorado               176.418242  -35.867527    3.807692
# Texas                  172.779614  -26.121259    3.780711
# Tennessee              167.551475  -29.189508    3.721311
# Ohio                   166.861834  -36.186354    3.750533
# Connecticut            163.223902   42.822439    3.426829
# Illinois               162.939228  -25.625996    3.750000
# Maine                  158.816250   56.811250    4.375000
# Arizona                157.508839  -15.303125    3.848214
# Iowa                   152.658667   39.460000    3.733333
# Oregon                 140.573468   -9.600565    4.024194
# North Dakota           131.415714   32.875714    4.285714
# New Mexico             129.284865   31.273784    4.081081
# Kansas                 121.429583   34.851667    3.083333
# South Dakota           109.630000   32.903333    3.500000
# #### CIDADE ####
#               Valor venda       Lucro  Quantidade
# Cidade
# Jamestown     2354.395000  642.885000    4.500000
# Cheyenne      1603.140000  100.200000    4.000000
# Bellingham    1263.413333  203.533333    8.000000
# Independence  1208.685000  487.830000    3.000000
# Burbank       1082.386667  254.843333    4.333333
# ...                   ...         ...         ...
# Ormond Beach     2.810000   -1.970000    3.000000
# Pensacola        2.210000   -1.480000    3.000000
# Jupiter          2.060000    0.150000    1.000000
# Elyria           1.820000   -1.400000    1.000000
# Abilene          1.390000   -3.760000    2.000000
#
# [531 rows x 3 columns]
# #### REGIÃO ####
#          Valor venda      Lucro  Quantidade
# Região
# South     241.803623  28.857623    3.832716
# East      238.336134  32.135671    3.728230
# West      226.493225  33.848917    3.829535
# Central   215.772604  17.092583    3.779595
# #### NOME DO VENDEDOR ####
#                   Valor venda       Lucro  Quantidade
# Nome do Vendedor
# Mitch Willingham  1751.293333  555.173333    4.333333
# Sean Miller       1669.538000 -132.050000    3.333333
# Tamara Chand      1587.685000  748.443333    3.500000
# Grant Thornton    1558.533333 -684.776667    4.333333
# Tom Ashbrook      1459.562000  470.379000    3.600000
# ...                       ...         ...         ...
# Susan Gilcrest       9.590000   -0.740000    3.400000
# Mitch Gastineau      8.370000   -0.620000    4.000000
# Roy Skaria           7.443333    3.193333    3.333333
# Lela Donovan         5.300000    0.460000    3.000000
# Thais Sissman        2.420000   -1.660000    2.000000
#
# [793 rows x 3 columns]

# %% [markdown]
# ## Total Venda Por Categoria

# %%
plt.figure(figsize=(8,4))
df.groupby("Categoria")["Valor venda"].sum().sort_values().plot(kind="bar")
plt.title("Total de Vendas por Categoria")
plt.ylabel("Valor de venda")
plt.xlabel("Categoria")
plt.show()

# %% [markdown]
# ## Lucro por estado

# %%
plt.figure(figsize=(10,4))
df.groupby("Estado")["Lucro"].sum().sort_values().plot(kind="bar")
plt.title("Lucro Total por Estado")
plt.ylabel("Lucro")
plt.xlabel("Estado")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Lucros por categoria

# %%
lucro_categoria = df.groupby('Categoria')['Lucro'].sum().reset_index()

# Plotando o gráfico de barras
plt.figure(figsize=(8,5))
plt.bar(lucro_categoria['Categoria'], lucro_categoria['Lucro'])
plt.title('Lucro por Categoria')
plt.xlabel('Categoria')
plt.ylabel('Lucro Total')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Lucros por Sub-Categoria

# %%
lucro_categoria = df.groupby('Sub-Categoria')['Lucro'].sum().reset_index()

# Plotando o gráfico de barras
plt.figure(figsize=(8,5))
plt.bar(lucro_categoria['Sub-Categoria'], lucro_categoria['Lucro'])
plt.title('Lucro por Categoria')
plt.xlabel('Categoria')
plt.ylabel('Lucro Total')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Quantidade vendida por segmento

# %%
plt.figure(figsize=(7,4))
df.groupby("Segmento")["Quantidade"].sum().plot(kind="bar")
plt.title("Quantidade vendida por Segmento")
plt.ylabel("Quantidade")
plt.xlabel("Segmento")
plt.show()

# %% [markdown]
# ## Passando Ponto Para Virgula

# %%
cols = ['Valor venda', 'Lucro', 'Valor Unitario', 'Quantidade', 'Desconto', 'Margem']

for col in cols:
    df[col] = df[col].astype(float).round(2)              # garante número com 2 casas
    df[col] = df[col].astype(str).str.replace('.', ',', regex=False)  # troca ponto por vírgula

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Linha ID          9994 non-null   object
#  1   ID Pedido         9994 non-null   object
#  2   Data do Pedido    9994 non-null   datetime64[ns]
#  3   Data do Envio     9994 non-null   datetime64[ns]
#  4   Mode de Envio     9994 non-null   object
#  5   ID Vendedor       9994 non-null   object
#  6   Nome do Vendedor  9994 non-null   object
#  7   Segmento          9994 non-null   object
#  8   Pais              9994 non-null   object
#  9   Cidade            9994 non-null   object
#  10  Estado            9994 non-null   object
#  11  Codigo Postal     9994 non-null   object
#  12  Região            9994 non-null   object
#  13  Produto ID        9994 non-null   object
#  14  Categoria         9994 non-null   object
#  15  Sub-Categoria     9994 non-null   object
#  16  Nome do Produto   9994 non-null   object
#  17  Valor venda       9994 non-null   object
#  18  Quantidade        9994 non-null   object
#  19  Desconto          9994 non-null   object
#  20  Lucro             9994 non-null   object
#  21  Ano               9994 non-null   int32
#  22  Mes               9994 non-null   int32
#  23  Dia               9994 non-null   int32
#  24  Envio Dias        9994 non-null   int64
#  25  Valor Unitario    9994 non-null   object
#  26  Margem            9994 non-null   object
# dtypes: datetime64[ns](2), int32(3), int64(1), object(21)
# memory usage: 1.9+ MB

# %%
df.head()
# Out:
#   Linha ID       ID Pedido Data do Pedido Data do Envio   Mode de Envio  \
# 0        1  CA-2013-152156     2013-11-09    2013-11-12    Second Class
# 1        2  CA-2013-152156     2013-11-09    2013-11-12    Second Class
# 2        3  CA-2013-138688     2013-06-13    2013-06-17    Second Class
# 3        4  US-2012-108966     2012-10-11    2012-10-18  Standard Class
# 4        5  US-2012-108966     2012-10-11    2012-10-18  Standard Class
#
#   ID Vendedor Nome do Vendedor   Segmento           Pais           Cidade  \
# 0    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1    CG-12520      Claire Gute   Consumer  United States        Henderson
# 2    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#    ... Valor venda Quantidade Desconto    Lucro   Ano Mes Dia Envio Dias  \
# 0  ...      261,96        2,0      0,0    41,91  2013  11   9          3
# 1  ...      731,94        3,0      0,0   219,58  2013  11   9          3
# 2  ...       14,62        2,0      0,0     6,87  2013   6  13          4
# 3  ...      957,58        5,0     45,0  -383,03  2012  10  11          7
# 4  ...       22,37        2,0     20,0     2,52  2012  10  11          7
#
#   Valor Unitario Margem
# 0         130,98   0,16
# 1         243,98    0,3
# 2           7,31   0,47
# 3         191,52   -0,4
# 4          11,18   0,11
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Exportando DataSet

# %%
df.to_csv("superstore_limpo.csv", index=False, sep=';', encoding='utf-8')
